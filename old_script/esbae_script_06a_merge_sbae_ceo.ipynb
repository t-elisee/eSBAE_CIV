# %% [markdown]
# # V - Merging esbae with CEO data
# ### This script serves to merge validated data from CEO with eSBAE points for quick estimation of areas
# #### This script requires minimum an m16 instance and select the python 3 kernel
# ###### For more information contact aurelie.shapiro@fao.org or remi.dannunzio@fao.org

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
# Set the display option to a large value to prevent text wrapping
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# #### combine all CEO sample files
# ##### download your CEO sample files from collect.earth and upload to SEPAL using FileZilla.
# ##### add as many files as you have projects

# %%
#all_csv_Côté D'Ivoire
grid_df = pd.read_csv('/home/sepal-user/CAFI_DDD/grid_1km_bon.csv')
pre_df = pd.read_csv('/home/sepal-user/CAFI_DDD/PREpoints_bon.csv')
points_835_df = pd.read_csv('/home/sepal-user/CAFI_DDD/835points_bon.csv')
points_3468_df = pd.read_csv('/home/sepal-user/CAFI_DDD/3468points_bon.csv')



#DRC
#ceo1 = pd.read_csv('/home/sepal-user/module_results/esbae/DRC/ceo-CAFI-DDD-RDC-eSBAE-validation-1-sample-data_prov.csv')
#ceo2 = pd.read_csv('/home/sepal-user/module_results/esbae/DRC/ceo-CAFI-DDD-RDC-eSBAE-validation-2-sample-data.csv')
#ceo3 = pd.read_csv('/home/sepal-user/module_results/esbae/DRC/ceo-CAFI-DDD-RDC-eSBAE-validation-3-sample-data.csv')
#GAB
#ceo1 = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/ceo-CAFI-DDD-Gabon-eSBAE-validation-1-sample-data.csv')
#ceo2 = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/ceo-CAFI-DDD-Gabon-eSBAE-validation-2-sample-data.csv')
#ceo3 = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/ceo-CAFI-DDD-Gabon-eSBAE-validation-3-sample-data.csv')
#ceo4 = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/ceo-CAFI-DDD-Gabon-eSBAE-validation-4-sample-data.csv')
#ceo5 = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/ceo-CAFI-DDD-Gabon-eSBAE-validation-5-sample-data.csv')

# %%
# Check if 'point_id' is one of the columns
if 'point_id' in grid_df.columns:
    print("The 'point_id' column exists.")
else:
    print("The 'point_id' column does not exist. Available columns are:", grid_df.columns.tolist())
# Out:
# The 'point_id' column exists.

# %%
#Rename the columns in pre_df and points_835_df to have a consistent point_id column for merging.
pre_df.rename(columns={'field_1': 'point_id'}, inplace=True)
points_835_df.rename(columns={'plot_id': 'point_id'}, inplace=True)

# %%
pre_df.head()
# Out:
#    point_id       LON       LAT  prob_chang  str_dal_ne      ID  INT1_2000  \
# 0      1001 -8.351661  6.426318    0.418537           3     4.0         23
# 1    100199 -6.535769  4.916170    0.111944           2   405.0         22
# 2      1002 -8.351808  6.435360    0.159422           2  1199.0         12
# 3    100224 -6.538023  5.142245    0.129246           2   531.0         21
# 4    100230 -6.538580  5.196502    0.060448           1  2418.0         22
#
#    INT1_2010  INT1_2015  INT1_2020  INT1_2021 CHG_00_10 CHG_10_15  \
# 0         50         50         50         23    Stable    Stable
# 1         22         22         22         22    Stable    Stable
# 2         12         12         21         21    Stable    Stable
# 3         21         21         23         23    Stable    Stable
# 4         22         22         22         22    Stable    Stable
#
#        CHG_15_20 CHG_20_21  IC                                   COMMENT  \
# 0         Stable    Stable   1                                       NaN
# 1         Stable    Stable   2  Doute pour l'ann├âãÆ├åÔÇÖ├âÔÇÜ├é┬®e 2000
# 2  Deforestation    Stable   1                                       NaN
# 3         Stable    Stable   1                                       NaN
# 4         Stable    Stable   2                                       NaN
#
#         phyto  str_dal_FA INT1_PI  INT2_2000  INT2_2010  INT2_2015  INT2_2020  \
# 0  ombrophile           3     AVO         23         50         50         50
# 1  ombrophile           2     NaN         22         22         22         22
# 2  ombrophile           2     AVQ         12         12         23         21
# 3  ombrophile           2     NaN         21         21         21         23
# 4  ombrophile           1     NaN         22         22         22         22
#
#    INT2_2021 INT2_PI CHG2_00_10     CHG2_10_15 CHG2_15_20 CHG2_20_21 COMMENT.
# 0         23     NaN     Stable         Stable     Stable     Stable      NaN
# 1         22     NaN     Stable         Stable     Stable     Stable      NaN
# 2         21      GJ     Stable  Deforestation     Stable     Stable      NaN
# 3         23     NaN     Stable         Stable     Stable     Stable      NaN
# 4         22     NaN     Stable         Stable     Stable     Stable      NaN

# %%
points_835_df.head()
# Out:
#    point_id       lon       lat                           email.1  \
# 0      1918 -8.305590  7.411937                yavofaty@gmail.com
# 1      2223 -8.290033  7.547567                yavofaty@gmail.com
# 2      2610 -8.255989  7.176838                 bahpm@outlook.com
# 3      3026 -8.227213  7.086417                yavofaty@gmail.com
# 4      3190 -8.219938  7.185882  visiondegloirenouvelle@gmail.com
#
#                        email.2 flagged.1 flagged.2 collection_time.1  \
# 0        zourasore22@gmail.com      faux      faux  06/01/2023 18:27
# 1        zourasore22@gmail.com      faux      faux  06/01/2023 18:46
# 2  kouassikoffiaymar@gmail.com      faux      faux     5/31/23 15:34
# 3        zourasore22@gmail.com      faux      faux     6/20/23 17:22
# 4         muller.yao@yahoo.com      faux      faux  06/01/2023 10:33
#
#   collection_time.2 analysis_duration.1 analysis_duration.2  \
# 0     6/20/23 17:16           39.6 secs         1397.8 secs
# 1  06/01/2023 18:10         1143.9 secs           48.5 secs
# 2  06/01/2023 14:44         1640.9 secs         1060.1 secs
# 3     5/31/23 22:41          255.1 secs        17516.9 secs
# 4     6/21/23 13:52          523.7 secs          247.1 secs
#
#        imagery_title.1             imagery_title.2  imagery_attributions.1  \
# 0                  NaN         Planet NICFI Public                     NaN
# 1     Mapbox Satellite            Mapbox Satellite                     NaN
# 2  Planet NICFI Public  Mapbox Satellite w/ Labels                     NaN
# 3     Mapbox Satellite            Mapbox Satellite                     NaN
# 4  Planet NICFI Public                         NaN                     NaN
#
#    imagery_attributions.2          ipcc2022.1          ipcc2022.2  \
# 0                     NaN  Terres forestieres  Terres forestieres
# 1                     NaN  Terres forestieres  Terres forestieres
# 2                     NaN    Terres cultivees    Terres cultivees
# 3                     NaN    Terres cultivees    Terres cultivees
# 4                     NaN    Terres cultivees    Terres cultivees
#
#   match_ipcc22          lc_2022.1          lc_2022.2 match_lc22  \
# 0         vrai        Foret dense        Foret dense       vrai
# 1         vrai        Foret dense      Foret gelerie       faux
# 2         vrai  Jachere ou fourre  Jachere ou fourre       vrai
# 3         vrai             Cacao              Cacao        vrai
# 4         vrai             Cacao              Cacao        vrai
#
#            ipcc2020.1          ipcc2020.2 match_ipcc20          lc_2020.1  \
# 0  Terres forestieres  Terres forestieres         vrai        Foret dense
# 1  Terres forestieres  Terres forestieres         vrai        Foret dense
# 2    Terres cultivees    Terres cultivees         vrai  Jachere ou fourre
# 3    Terres cultivees    Terres cultivees         vrai             Cacao
# 4    Terres cultivees    Terres cultivees         vrai             Cacao
#
#            lc_2020.2 match_lc20 luc_2020_2022.1 luc_2020_2022.2  \
# 0        Foret dense       vrai          Stable          Stable
# 1      Foret gelerie       faux          Stable          Stable
# 2  Jachere ou fourre       vrai          Stable          Stable
# 3             Cacao        vrai          Stable          Stable
# 4             Cacao        vrai          Stable          Stable
#
#   match_luc20_22          ipcc2015.1          ipcc2015.2 match_ipcc15  \
# 0           vrai  Terres forestieres  Terres forestieres         vrai
# 1           vrai  Terres forestieres  Terres forestieres         vrai
# 2           vrai    Terres cultivees    Terres cultivees         vrai
# 3           vrai    Terres cultivees    Terres cultivees         vrai
# 4           vrai    Terres cultivees    Terres cultivees         faux
#
#            lc_2015.1          lc_2015.2 match_lc15 luc_2015_2020.1  \
# 0        Foret dense        Foret dense       vrai          Stable
# 1        Foret dense      Foret gelerie       faux          Stable
# 2  Jachere ou fourre  Jachere ou fourre       vrai          Stable
# 3             Cacao              Cacao        vrai          Stable
# 4             Cacao              Cacao        vrai          Stable
#
#   luc_2015_2020.2 match_luc15_20  luc_yr.1  luc_yr.2 match_luc_yr Confiance.1  \
# 0          Stable           vrai       NaN       NaN          NaN       Eleve
# 1          Stable           vrai       NaN       NaN          NaN       Eleve
# 2          Stable           vrai       NaN       NaN          NaN       Eleve
# 3          Stable           vrai       NaN       NaN          NaN       Eleve
# 4          Stable           vrai       NaN       NaN          NaN       Eleve
#
#   Confiance.2 match_confiance
# 0       Moyen            faux
# 1       Moyen            faux
# 2       Eleve            vrai
# 3       Eleve            vrai
# 4       Eleve            vrai

# %%
merged_df = grid_df.merge(pre_df, on='point_id', how='outer', suffixes=('_grid', '_pre'))
merged_df = merged_df.merge(points_835_df, on='point_id', how='outer')

# %%
if 'lon' in merged_df.columns and 'lat' in merged_df.columns and \
   'lon' in points_3468_df.columns and 'lat' in points_3468_df.columns:
    print("Both DataFrames contain 'lon' and 'lat' columns.")
else:
    print("One of the DataFrames does not contain the 'lon' and 'lat' columns.")
# Out:
# Both DataFrames contain 'lon' and 'lat' columns.

# %%
# Perform the merge
merged_df_with_3468 = pd.merge(
    merged_df,
    points_3468_df,
    on=['lon', 'lat'],
    how='inner'  # or 'outer', 'left', 'right' depending on the desired result
)

# %%
print(merged_df_with_3468.head(2))
# Out:
#       fid  point_id       LON_grid  PLOTID      LAT_grid  LON_pre  LAT_pre  \
# 0   71983     72898 -768899.669023   72898  1.058615e+06      NaN      NaN
# 1  199012    200349 -559899.669023  200349  1.024615e+06      NaN      NaN
#
#    prob_chang  str_dal_ne  ID  INT1_2000  INT1_2010  INT1_2015  INT1_2020  \
# 0         NaN         NaN NaN        NaN        NaN        NaN        NaN
# 1         NaN         NaN NaN        NaN        NaN        NaN        NaN
#
#    INT1_2021 CHG_00_10 CHG_10_15 CHG_15_20 CHG_20_21  IC COMMENT phyto  \
# 0        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
# 1        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
#
#    str_dal_FA INT1_PI  INT2_2000  INT2_2010  INT2_2015  INT2_2020  INT2_2021  \
# 0         NaN     NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN     NaN        NaN        NaN        NaN        NaN        NaN
#
#   INT2_PI CHG2_00_10 CHG2_10_15 CHG2_15_20 CHG2_20_21 COMMENT.       lon  \
# 0     NaN        NaN        NaN        NaN        NaN      NaN -7.004035
# 1     NaN        NaN        NaN        NaN        NaN      NaN -5.095713
#
#         lat                           email.1                email.2  \
# 0  9.572903  visiondegloirenouvelle@gmail.com   muller.yao@yahoo.com
# 1  9.265501           dibidieudonne@gmail.com  charleskramo@yahoo.fr
#
#   flagged.1 flagged.2 collection_time.1 collection_time.2 analysis_duration.1  \
# 0      faux      faux     6/21/23 14:54     6/21/23 14:24           70.6 secs
# 1      faux      faux       45063,61319       45064,31667           87.0 secs
#
#   analysis_duration.2   imagery_title.1      imagery_title.2  \
# 0          167.7 secs  Mapbox Satellite                  NaN
# 1          305.5 secs  Mapbox Satellite  Planet NICFI Public
#
#    imagery_attributions.1  imagery_attributions.2          ipcc2022.1  \
# 0                     NaN                     NaN    Terres cultivees
# 1                     NaN                     NaN  Terre gramineennes
#
#            ipcc2022.2 match_ipcc22             lc_2022.1  \
# 0    Terres cultivees         vrai  Amenagement agricole
# 1  Terre gramineennes         vrai      Savane arbustive
#
#               lc_2022.2 match_lc22           ipcc2020.1           ipcc2020.2  \
# 0  Amenagement agricole       vrai     Terres cultivees     Terres cultivees
# 1        Savane arboree       faux  Terres gramineennes  Terres gramineennes
#
#   match_ipcc20             lc_2020.1             lc_2020.2 match_lc20  \
# 0         vrai  Amenagement agricole  Amenagement agricole       vrai
# 1         vrai      Savane arbustive        Savane arboree       faux
#
#   luc_2020_2022.1 luc_2020_2022.2 match_luc20_22           ipcc2015.1  \
# 0          Stable          Stable           vrai   Terres forestieres
# 1          Stable          Stable           vrai  Terres gramineennes
#
#             ipcc2015.2 match_ipcc15         lc_2015.1       lc_2015.2  \
# 0   Terres forestieres         vrai       Foret dense     Foret dense
# 1  Terres gramineennes         vrai  Savane arbustive  Savane arboree
#
#   match_lc15 luc_2015_2020.1 luc_2015_2020.2 match_luc15_20  luc_yr.1  \
# 0       vrai     Degradation   Deforestation           faux    2016.0
# 1       faux          Stable          Stable           vrai       NaN
#
#    luc_yr.2 match_luc_yr Confiance.1 Confiance.2 match_confiance  plotid  \
# 0    2019.0        False       Eleve       Eleve            vrai    7807
# 1       NaN          NaN       Eleve       Eleve            vrai    2820
#
#    sampleid                        email flagged      collection_time  \
# 0      7807        gdr95zamble@gmail.com    faux  2023/10/06 00:20:00
# 1      2820  kouassikoffiaymar@gmail.com    faux  2023/10/04 16:30:00
#
#   analysis_duration     imagery_title  imagery_attributions  \
# 0         92.4 secs  Mapbox Satellite                   NaN
# 1       3684.3 secs  Mapbox Satellite                   NaN
#
#                                    sample_geom       pl_layer  \
# 0  POINT(-7.004035500000002 9.572902999999998)     points_k=0
# 1  POINT(-5.095713000000002 9.265500999999999)  points_10%k=1
#
#        Occupation 2020 EH-Niveau 2 (2020) Infrastructures-Niveau 3(2020)  \
# 0   Terres forestieres                NaN                            NaN
# 1  Terres gramineennes                NaN                            NaN
#
#   TG-Niveau 2 (2020) TF - Niveau 2 – (2020) Foret dense- Niveau 3 - (2020)  \
# 0                NaN            Foret dense                   Foret claire
# 1     Savane arboree                    NaN                            NaN
#
#   Foret sur sol hydromorphe-Niveau 3-(2020)  \
# 0                                       NaN
# 1                                       NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2020)  \
# 0                                          NaN
# 1                                          NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2020) TH-Niveau 2 (2020)  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
#
#   Plan eau-Niveau 3(2020) Cours et voie eau-Niveau 3 (2020)  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
#
#   TC-Niveau-2 (2020) Cacao-Niveau-3 (2020) Hevea-Niveau-3 (2020)  \
# 0                NaN                   NaN                   NaN
# 1                NaN                   NaN                   NaN
#
#    Cafe-Niveau-3 (2020) Amenagement agricole-Niveau-3 (2020)  \
# 0                   NaN                                  NaN
# 1                   NaN                                  NaN
#
#   AT-Niveau 2 (2020)      Occupation 2015 TH-Niveau 2 (2015)  \
# 0                NaN   Terres forestieres                NaN
# 1                NaN  Terres gramineennes                NaN
#
#   Cours et voie eau-Niveau 3(2015) Plan eau-Niveau 3(2015) AT-Niveau 2 (2015)  \
# 0                              NaN                     NaN                NaN
# 1                              NaN                     NaN                NaN
#
#   TC-Niveau-2-2015 Hevea-Niveau-3 (2015) Amenagement agricole-Niveau-3 (2015)  \
# 0              NaN                   NaN                                  NaN
# 1              NaN                   NaN                                  NaN
#
#    Cafe-Niveau-3 (2015) Cacao-Niveau-3 (2015) TF - Niveau 2 – (2015)  \
# 0                   NaN                   NaN            Foret dense
# 1                   NaN                   NaN                    NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2015)  \
# 0                                                  NaN
# 1                                                  NaN
#
#   Foret sur sol hydromorphe-Niveau 3-(2015) Foret dense - Niveau 3-(2015)  \
# 0                                       NaN                  Foret claire
# 1                                       NaN                           NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2015) EH-Niveau 2 (2015)  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
#
#   Infrastructures-Niveau 3(2015) TG-Niveau 2(2015) Changement 2015-2020  \
# 0                            NaN               NaN               Stable
# 1                            NaN    Savane arboree               Stable
#
#   Moteur de deforestation 2015-2020  Annee de Degradation 2015-2020  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
#
#   Moteur de degradation 2015-2020  Annee de Deforestation 2015-2020  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
#
#    Gain 2015-2020     Occupation 2022 TF - Niveau 2 – (2022)  \
# 0             NaN  Terres forestieres            Foret dense
# 1             NaN  Terre gramineennes                    NaN
#
#   Foret dense- Niveau 3 - (2022) Foret sur sol hydromorphe-Niveau 3-(2022)  \
# 0                   Foret claire                                       NaN
# 1                            NaN                                       NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2022)  \
# 0                                                  NaN
# 1                                                  NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2022) TG-Niveau 2 (2022)  \
# 0                                          NaN                NaN
# 1                                          NaN     Savane arboree
#
#   EH-Niveau 2 (2022) Infrastructures-Niveau 3(2022) TC-Niveau-2 (2022)  \
# 0                NaN                            NaN                NaN
# 1                NaN                            NaN                NaN
#
#   Amenagement agricole-Niveau-3 (2022)  Cafe-Niveau-3 (2022)  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
#
#   Hevea-Niveau-3 (2022) Cacao-Niveau-3 (2022) AT-Niveau 2 (2022)  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
#
#   TH-Niveau 2 (2022) Plan eau-Niveau 3(2022)  \
# 0                NaN                     NaN
# 1                NaN                     NaN
#
#   Cours et voie eau-Niveau 3 (2022) Changement 2020-2022  \
# 0                               NaN               Stable
# 1                               NaN               Stable
#
#    Annee de Deforestation 2020-2022 Moteur de deforestation 2020-2022  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
#
#    Gain 2020-2022  Annee de Degradation 2020-2022  \
# 0             NaN                             NaN
# 1             NaN                             NaN
#
#   Moteur de degradation 2020-2022 Confiance  Ajouter un commentaire
# 0                             NaN     Eleve  Ajouter un commentaire
# 1                             NaN     Eleve  Ajouter un commentaire

# %%
merged_df_with_3468.to_csv('/home/sepal-user/CAFI_DDD/merge_bon.csv', index=False)


# To save the merged dataframe to a new CSV file
#merged_df.to_csv('path_to/merged_dataset.csv', index=False)

# %%
ceo1.head(3)
# Out:
#    field_1       LON       LAT  prob_chang  str_dal_ne      ID  INT1_2000  \
# 0     1001 -8.351661  6.426318    0.418537           3     4.0         23
# 1   100199 -6.535769  4.916170    0.111944           2   405.0         22
# 2     1002 -8.351808  6.435360    0.159422           2  1199.0         12
#
#    INT1_2010  INT1_2015  INT1_2020  INT1_2021 CHG_00_10 CHG_10_15  \
# 0         50         50         50         23    Stable    Stable
# 1         22         22         22         22    Stable    Stable
# 2         12         12         21         21    Stable    Stable
#
#        CHG_15_20 CHG_20_21  IC                                   COMMENT  \
# 0         Stable    Stable   1                                       NaN
# 1         Stable    Stable   2  Doute pour l'ann├âãÆ├åÔÇÖ├âÔÇÜ├é┬®e 2000
# 2  Deforestation    Stable   1                                       NaN
#
#         phyto  str_dal_FA INT1_PI  INT2_2000  INT2_2010  INT2_2015  INT2_2020  \
# 0  ombrophile           3     AVO         23         50         50         50
# 1  ombrophile           2     NaN         22         22         22         22
# 2  ombrophile           2     AVQ         12         12         23         21
#
#    INT2_2021 INT2_PI CHG2_00_10     CHG2_10_15 CHG2_15_20 CHG2_20_21 COMMENT.
# 0         23     NaN     Stable         Stable     Stable     Stable      NaN
# 1         22     NaN     Stable         Stable     Stable     Stable      NaN
# 2         21      GJ     Stable  Deforestation     Stable     Stable      NaN

# %%
ceo2.head(3)
# Out:
#    plot_id       lon       lat             email.1  \
# 0     1918 -8.305590  7.411937  yavofaty@gmail.com
# 1     2223 -8.290033  7.547567  yavofaty@gmail.com
# 2     2610 -8.255989  7.176838   bahpm@outlook.com
#
#                        email.2 flagged.1 flagged.2 collection_time.1  \
# 0        zourasore22@gmail.com      faux      faux  06/01/2023 18:27
# 1        zourasore22@gmail.com      faux      faux  06/01/2023 18:46
# 2  kouassikoffiaymar@gmail.com      faux      faux     5/31/23 15:34
#
#   collection_time.2 analysis_duration.1 analysis_duration.2  \
# 0     6/20/23 17:16           39.6 secs         1397.8 secs
# 1  06/01/2023 18:10         1143.9 secs           48.5 secs
# 2  06/01/2023 14:44         1640.9 secs         1060.1 secs
#
#        imagery_title.1             imagery_title.2  imagery_attributions.1  \
# 0                  NaN         Planet NICFI Public                     NaN
# 1     Mapbox Satellite            Mapbox Satellite                     NaN
# 2  Planet NICFI Public  Mapbox Satellite w/ Labels                     NaN
#
#    imagery_attributions.2          ipcc2022.1          ipcc2022.2  \
# 0                     NaN  Terres forestieres  Terres forestieres
# 1                     NaN  Terres forestieres  Terres forestieres
# 2                     NaN    Terres cultivees    Terres cultivees
#
#   match_ipcc22          lc_2022.1          lc_2022.2 match_lc22  \
# 0         vrai        Foret dense        Foret dense       vrai
# 1         vrai        Foret dense      Foret gelerie       faux
# 2         vrai  Jachere ou fourre  Jachere ou fourre       vrai
#
#            ipcc2020.1          ipcc2020.2 match_ipcc20          lc_2020.1  \
# 0  Terres forestieres  Terres forestieres         vrai        Foret dense
# 1  Terres forestieres  Terres forestieres         vrai        Foret dense
# 2    Terres cultivees    Terres cultivees         vrai  Jachere ou fourre
#
#            lc_2020.2 match_lc20 luc_2020_2022.1 luc_2020_2022.2  \
# 0        Foret dense       vrai          Stable          Stable
# 1      Foret gelerie       faux          Stable          Stable
# 2  Jachere ou fourre       vrai          Stable          Stable
#
#   match_luc20_22          ipcc2015.1          ipcc2015.2 match_ipcc15  \
# 0           vrai  Terres forestieres  Terres forestieres         vrai
# 1           vrai  Terres forestieres  Terres forestieres         vrai
# 2           vrai    Terres cultivees    Terres cultivees         vrai
#
#            lc_2015.1          lc_2015.2 match_lc15 luc_2015_2020.1  \
# 0        Foret dense        Foret dense       vrai          Stable
# 1        Foret dense      Foret gelerie       faux          Stable
# 2  Jachere ou fourre  Jachere ou fourre       vrai          Stable
#
#   luc_2015_2020.2 match_luc15_20  luc_yr.1  luc_yr.2 match_luc_yr Confiance.1  \
# 0          Stable           vrai       NaN       NaN          NaN       Eleve
# 1          Stable           vrai       NaN       NaN          NaN       Eleve
# 2          Stable           vrai       NaN       NaN          NaN       Eleve
#
#   Confiance.2 match_confiance
# 0       Moyen            faux
# 1       Moyen            faux
# 2       Eleve            vrai

# %%
ceo3.head(3)
# Out:
#    plotid  sampleid       lon       lat                        email flagged  \
# 0       7         7 -5.821402  5.657688  kouassikoffiaymar@gmail.com    faux
# 1      16        16 -5.552350  5.838547  kouassikoffiaymar@gmail.com    faux
# 2      71        71 -6.563582  6.561957  kouassikoffiaymar@gmail.com    faux
#
#        collection_time analysis_duration     imagery_title  \
# 0  2023/10/02 21:14:00       4274.4 secs  Mapbox Satellite
# 1  2023/08/11 21:19:00       3823.3 secs  Mapbox Satellite
# 2  2023/08/10 08:22:00       3768.9 secs  Mapbox Satellite
#
#    imagery_attributions                          sample_geom       pl_layer  \
# 0                   NaN  POINT(-5.821402000000002 5.6576885)  points_10%k=1
# 1                   NaN           POINT(-5.5523495 5.838547)  points_10%k=1
# 2                   NaN   POINT(-6.563582000000002 6.561957)  points_10%k=1
#
#     Occupation 2020 EH-Niveau 2 (2020) Infrastructures-Niveau 3(2020)  \
# 0  Terres cultivees                NaN                            NaN
# 1  Terres cultivees                NaN                            NaN
# 2  Terres cultivees                NaN                            NaN
#
#   TG-Niveau 2 (2020) TF - Niveau 2 – (2020) Foret dense- Niveau 3 - (2020)  \
# 0                NaN                    NaN                            NaN
# 1                NaN                    NaN                            NaN
# 2                NaN                    NaN                            NaN
#
#   Foret sur sol hydromorphe-Niveau 3-(2020)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2020)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2020) TH-Niveau 2 (2020)  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
#
#   Plan eau-Niveau 3(2020) Cours et voie eau-Niveau 3 (2020)  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
# 2                     NaN                               NaN
#
#      TC-Niveau-2 (2020) Cacao-Niveau-3 (2020) Hevea-Niveau-3 (2020)  \
# 0  Amenagement agricole                   NaN                   NaN
# 1  Amenagement agricole                   NaN                   NaN
# 2  Amenagement agricole                   NaN                   NaN
#
#    Cafe-Niveau-3 (2020) Amenagement agricole-Niveau-3 (2020)  \
# 0                   NaN                      Sol nu agricole
# 1                   NaN                      Sol nu agricole
# 2                   NaN                      Sol nu agricole
#
#   AT-Niveau 2 (2020)   Occupation 2015 TH-Niveau 2 (2015)  \
# 0                NaN  Terres cultivees                NaN
# 1                NaN  Terres cultivees                NaN
# 2                NaN  Terres cultivees                NaN
#
#   Cours et voie eau-Niveau 3(2015) Plan eau-Niveau 3(2015) AT-Niveau 2 (2015)  \
# 0                              NaN                     NaN                NaN
# 1                              NaN                     NaN                NaN
# 2                              NaN                     NaN                NaN
#
#        TC-Niveau-2-2015 Hevea-Niveau-3 (2015)  \
# 0  Amenagement agricole                   NaN
# 1  Amenagement agricole                   NaN
# 2     Jachere ou fourre                   NaN
#
#   Amenagement agricole-Niveau-3 (2015)  Cafe-Niveau-3 (2015)  \
# 0                      Sol nu agricole                   NaN
# 1        Recrus herbeux post culturaux                   NaN
# 2                                  NaN                   NaN
#
#   Cacao-Niveau-3 (2015) TF - Niveau 2 – (2015)  \
# 0                   NaN                    NaN
# 1                   NaN                    NaN
# 2                   NaN                    NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2015)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
#
#   Foret sur sol hydromorphe-Niveau 3-(2015) Foret dense - Niveau 3-(2015)  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2015) EH-Niveau 2 (2015)  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
#
#   Infrastructures-Niveau 3(2015) TG-Niveau 2(2015) Changement 2015-2020  \
# 0                            NaN               NaN               Stable
# 1                            NaN               NaN               Stable
# 2                            NaN               NaN               Stable
#
#   Moteur de deforestation 2015-2020  Annee de Degradation 2015-2020  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
#
#   Moteur de degradation 2015-2020  Annee de Deforestation 2015-2020  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
#
#    Gain 2015-2020   Occupation 2022 TF - Niveau 2 – (2022)  \
# 0             NaN  Terres cultivees                    NaN
# 1             NaN  Terres cultivees                    NaN
# 2             NaN  Terres cultivees                    NaN
#
#   Foret dense- Niveau 3 - (2022) Foret sur sol hydromorphe-Niveau 3-(2022)  \
# 0                            NaN                                       NaN
# 1                            NaN                                       NaN
# 2                            NaN                                       NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2022)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2022) TG-Niveau 2 (2022)  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
#
#   EH-Niveau 2 (2022) Infrastructures-Niveau 3(2022)    TC-Niveau-2 (2022)  \
# 0                NaN                            NaN  Amenagement agricole
# 1                NaN                            NaN  Amenagement agricole
# 2                NaN                            NaN  Amenagement agricole
#
#   Amenagement agricole-Niveau-3 (2022)  Cafe-Niveau-3 (2022)  \
# 0                      Sol nu agricole                   NaN
# 1                      Sol nu agricole                   NaN
# 2                      Sol nu agricole                   NaN
#
#   Hevea-Niveau-3 (2022) Cacao-Niveau-3 (2022) AT-Niveau 2 (2022)  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                   NaN                   NaN                NaN
#
#   TH-Niveau 2 (2022) Plan eau-Niveau 3(2022)  \
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
#
#   Cours et voie eau-Niveau 3 (2022) Changement 2020-2022  \
# 0                               NaN               Stable
# 1                               NaN               Stable
# 2                               NaN               Stable
#
#    Annee de Deforestation 2020-2022 Moteur de deforestation 2020-2022  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
#
#    Gain 2020-2022  Annee de Degradation 2020-2022  \
# 0             NaN                             NaN
# 1             NaN                             NaN
# 2             NaN                             NaN
#
#   Moteur de degradation 2020-2022 Confiance  Ajouter un commentaire
# 0                             NaN     Eleve  Ajouter un commentaire
# 1                             NaN     Eleve  Ajouter un commentaire
# 2                             NaN     Eleve  Ajouter un commentaire

# %%
ceo_files = [ceo1, ceo2, ceo3]

# %%
ceo_files_col = ceo_files.columns.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 column_names = ceo_files.tolist()
#       2 # Print the list of column names
#       3 print(column_names)
#
# AttributeError: 'list' object has no attribute 'tolist'

# %% [markdown]
# ##### drop duplicates from ceo collections
# ###### keep first duplicate by date

# %%
column_names = ceo3.columns.tolist()
# Print the list of column names
print(column_names)
# Out:
# ['plotid', 'sampleid', 'lon', 'lat', 'email', 'flagged', 'collection_time', 'analysis_duration', 'imagery_title', 'imagery_attributions', 'sample_geom', 'pl_layer', 'Occupation 2020', 'EH-Niveau 2 (2020)', 'Infrastructures-Niveau 3(2020)', 'TG-Niveau 2 (2020)', 'TF - Niveau 2 – (2020)', 'Foret dense- Niveau 3 - (2020)', 'Foret sur sol hydromorphe-Niveau 3-(2020)', 'Foret secondaire ou degradee-Niveau 3-(2020)', 'Plantation forestiere ou reboisement-Niveau 3-(2020)', 'TH-Niveau 2 (2020)', 'Plan eau-Niveau 3(2020)', 'Cours et voie eau-Niveau 3 (2020)', 'TC-Niveau-2 (2020)', 'Cacao-Niveau-3 (2020)', 'Hevea-Niveau-3 (2020)', 'Cafe-Niveau-3 (2020)', 'Amenagement agricole-Niveau-3 (2020)', 'AT-Niveau 2 (2020)', 'Occupation 2015', 'TH-Niveau 2 (2015)', 'Cours et voie eau-Niveau 3(2015)', 'Plan eau-Niveau 3(2015)', 'AT-Niveau 2 (2015)', 'TC-Niveau-2-2015', 'Hevea-Niveau-3 (2015)', 'Amenagement agricole-Niveau-3 (2015)', 'Cafe-Niveau-3 (2015)', 'Cacao-Niveau-3 (2015)', 'TF - Niveau 2 – (2015)', 'Plantation forestiere ou reboisement-Niveau 3-(2015)', 'Foret sur sol hydromorphe-Niveau 3-(2015)', 'Foret dense - Niveau 3-(2015)', 'Foret secondaire ou degradee-Niveau 3-(2015)', 'EH-Niveau 2 (2015)', 'Infrastructures-Niveau 3(2015)', 'TG-Niveau 2(2015)', 'Changement 2015-2020', 'Moteur de deforestation 2015-2020', 'Annee de Degradation 2015-2020', 'Moteur de degradation 2015-2020', 'Annee de Deforestation 2015-2020', 'Gain 2015-2020', 'Occupation 2022', 'TF - Niveau 2 – (2022)', 'Foret dense- Niveau 3 - (2022)', 'Foret sur sol hydromorphe-Niveau 3-(2022)', 'Plantation forestiere ou reboisement-Niveau 3-(2022)', 'Foret secondaire ou degradee-Niveau 3-(2022)', 'TG-Niveau 2 (2022)', 'EH-Niveau 2 (2022)', 'Infrastructures-Niveau 3(2022)', 'TC-Niveau-2 (2022)', 'Amenagement agricole-Niveau-3 (2022)', 'Cafe-Niveau-3 (2022)', 'Hevea-Niveau-3 (2022)', 'Cacao-Niveau-3 (2022)', 'AT-Niveau 2 (2022)', 'TH-Niveau 2 (2022)', 'Plan eau-Niveau 3(2022)', 'Cours et voie eau-Niveau 3 (2022)', 'Changement 2020-2022', 'Annee de Deforestation 2020-2022', 'Moteur de deforestation 2020-2022', 'Gain 2020-2022', 'Annee de Degradation 2020-2022', 'Moteur de degradation 2020-2022', 'Confiance', 'Ajouter un commentaire']

# %%
print(ceo_files.dtypes)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(ceo_files.dtypes)
#
# AttributeError: 'list' object has no attribute 'dtypes'

# %%
ceo.head()
# Out:
#    fid  plot_id       lon       lat                           email.1  \
# 0    1   1918.0 -8.305590  7.411937                yavofaty@gmail.com
# 1    2   2223.0 -8.290033  7.547567                yavofaty@gmail.com
# 2    3   2610.0 -8.255989  7.176838                 bahpm@outlook.com
# 3    4   3026.0 -8.227213  7.086417                yavofaty@gmail.com
# 4    5   3190.0 -8.219938  7.185882  visiondegloirenouvelle@gmail.com
#
#                        email.2 flagged.1 flagged.2 collection_time.1  \
# 0        zourasore22@gmail.com      faux      faux  06/01/2023 18:27
# 1        zourasore22@gmail.com      faux      faux  06/01/2023 18:46
# 2  kouassikoffiaymar@gmail.com      faux      faux     5/31/23 15:34
# 3        zourasore22@gmail.com      faux      faux     6/20/23 17:22
# 4         muller.yao@yahoo.com      faux      faux  06/01/2023 10:33
#
#   collection_time.2 analysis_duration.1 analysis_duration.2  \
# 0     6/20/23 17:16           39.6 secs         1397.8 secs
# 1  06/01/2023 18:10         1143.9 secs           48.5 secs
# 2  06/01/2023 14:44         1640.9 secs         1060.1 secs
# 3     5/31/23 22:41          255.1 secs        17516.9 secs
# 4     6/21/23 13:52          523.7 secs          247.1 secs
#
#        imagery_title.1             imagery_title.2  imagery_attributions.1  \
# 0                  NaN         Planet NICFI Public                     NaN
# 1     Mapbox Satellite            Mapbox Satellite                     NaN
# 2  Planet NICFI Public  Mapbox Satellite w/ Labels                     NaN
# 3     Mapbox Satellite            Mapbox Satellite                     NaN
# 4  Planet NICFI Public                         NaN                     NaN
#
#    imagery_attributions.2          ipcc2022.1          ipcc2022.2  \
# 0                     NaN  Terres forestieres  Terres forestieres
# 1                     NaN  Terres forestieres  Terres forestieres
# 2                     NaN    Terres cultivees    Terres cultivees
# 3                     NaN    Terres cultivees    Terres cultivees
# 4                     NaN    Terres cultivees    Terres cultivees
#
#   match_ipcc22          lc_2022.1          lc_2022.2 match_lc22  \
# 0         vrai        Foret dense        Foret dense       vrai
# 1         vrai        Foret dense      Foret gelerie       faux
# 2         vrai  Jachere ou fourre  Jachere ou fourre       vrai
# 3         vrai              Cacao              Cacao       vrai
# 4         vrai              Cacao              Cacao       vrai
#
#            ipcc2020.1          ipcc2020.2 match_ipcc20          lc_2020.1  \
# 0  Terres forestieres  Terres forestieres         vrai        Foret dense
# 1  Terres forestieres  Terres forestieres         vrai        Foret dense
# 2    Terres cultivees    Terres cultivees         vrai  Jachere ou fourre
# 3    Terres cultivees    Terres cultivees         vrai              Cacao
# 4    Terres cultivees    Terres cultivees         vrai              Cacao
#
#            lc_2020.2 match_lc20 luc_2020_2022.1 luc_2020_2022.2  \
# 0        Foret dense       vrai          Stable          Stable
# 1      Foret gelerie       faux          Stable          Stable
# 2  Jachere ou fourre       vrai          Stable          Stable
# 3              Cacao       vrai          Stable          Stable
# 4              Cacao       vrai          Stable          Stable
#
#   match_luc20_22          ipcc2015.1          ipcc2015.2 match_ipcc15  \
# 0           vrai  Terres forestieres  Terres forestieres         vrai
# 1           vrai  Terres forestieres  Terres forestieres         vrai
# 2           vrai    Terres cultivees    Terres cultivees         vrai
# 3           vrai    Terres cultivees    Terres cultivees         vrai
# 4           vrai    Terres cultivees    Terres cultivees         faux
#
#            lc_2015.1          lc_2015.2 match_lc15 luc_2015_2020.1  \
# 0        Foret dense        Foret dense       vrai          Stable
# 1        Foret dense      Foret gelerie       faux          Stable
# 2  Jachere ou fourre  Jachere ou fourre       vrai          Stable
# 3              Cacao              Cacao       vrai          Stable
# 4              Cacao              Cacao       vrai          Stable
#
#   luc_2015_2020.2 match_luc15_20  luc_yr.1  luc_yr.2 match_luc_yr Confiance.1  \
# 0          Stable           vrai       NaN       NaN          NaN       Eleve
# 1          Stable           vrai       NaN       NaN          NaN       Eleve
# 2          Stable           vrai       NaN       NaN          NaN       Eleve
# 3          Stable           vrai       NaN       NaN          NaN       Eleve
# 4          Stable           vrai       NaN       NaN          NaN       Eleve
#
#   Confiance.2 match_confiance  plotid  sampleid email flagged collection_time  \
# 0       Moyen            faux     NaN       NaN   NaN     NaN             NaN
# 1       Moyen            faux     NaN       NaN   NaN     NaN             NaN
# 2       Eleve            vrai     NaN       NaN   NaN     NaN             NaN
# 3       Eleve            vrai     NaN       NaN   NaN     NaN             NaN
# 4       Eleve            vrai     NaN       NaN   NaN     NaN             NaN
#
#   analysis_duration imagery_title  imagery_attributions sample_geom pl_layer  \
# 0               NaN           NaN                   NaN         NaN      NaN
# 1               NaN           NaN                   NaN         NaN      NaN
# 2               NaN           NaN                   NaN         NaN      NaN
# 3               NaN           NaN                   NaN         NaN      NaN
# 4               NaN           NaN                   NaN         NaN      NaN
#
#   Occupation 2020 EH-Niveau 2 (2020) Infrastructures-Niveau 3(2020)  \
# 0             NaN                NaN                            NaN
# 1             NaN                NaN                            NaN
# 2             NaN                NaN                            NaN
# 3             NaN                NaN                            NaN
# 4             NaN                NaN                            NaN
#
#   TG-Niveau 2 (2020) TF - Niveau 2 – (2020) Foret dense- Niveau 3 - (2020)  \
# 0                NaN                    NaN                            NaN
# 1                NaN                    NaN                            NaN
# 2                NaN                    NaN                            NaN
# 3                NaN                    NaN                            NaN
# 4                NaN                    NaN                            NaN
#
#   Foret sur sol hydromorphe-Niveau 3-(2020)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2020)  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2020) TH-Niveau 2 (2020)  \
# 0                                                  NaN                NaN
# 1                                                  NaN                NaN
# 2                                                  NaN                NaN
# 3                                                  NaN                NaN
# 4                                                  NaN                NaN
#
#   Plan eau-Niveau 3(2020) Cours et voie eau-Niveau 3 (2020)  \
# 0                     NaN                               NaN
# 1                     NaN                               NaN
# 2                     NaN                               NaN
# 3                     NaN                               NaN
# 4                     NaN                               NaN
#
#   TC-Niveau-2 (2020) Cacao-Niveau-3 (2020) Hevea-Niveau-3 (2020)  \
# 0                NaN                   NaN                   NaN
# 1                NaN                   NaN                   NaN
# 2                NaN                   NaN                   NaN
# 3                NaN                   NaN                   NaN
# 4                NaN                   NaN                   NaN
#
#    Cafe-Niveau-3 (2020) Amenagement agricole-Niveau-3 (2020)  \
# 0                   NaN                                  NaN
# 1                   NaN                                  NaN
# 2                   NaN                                  NaN
# 3                   NaN                                  NaN
# 4                   NaN                                  NaN
#
#   AT-Niveau 2 (2020) Occupation 2015 TH-Niveau 2 (2015)  \
# 0                NaN             NaN                NaN
# 1                NaN             NaN                NaN
# 2                NaN             NaN                NaN
# 3                NaN             NaN                NaN
# 4                NaN             NaN                NaN
#
#   Cours et voie eau-Niveau 3(2015) Plan eau-Niveau 3(2015) AT-Niveau 2 (2015)  \
# 0                              NaN                     NaN                NaN
# 1                              NaN                     NaN                NaN
# 2                              NaN                     NaN                NaN
# 3                              NaN                     NaN                NaN
# 4                              NaN                     NaN                NaN
#
#   TC-Niveau-2-2015 Hevea-Niveau-3 (2015) Amenagement agricole-Niveau-3 (2015)  \
# 0              NaN                   NaN                                  NaN
# 1              NaN                   NaN                                  NaN
# 2              NaN                   NaN                                  NaN
# 3              NaN                   NaN                                  NaN
# 4              NaN                   NaN                                  NaN
#
#    Cafe-Niveau-3 (2015) Cacao-Niveau-3 (2015) TF - Niveau 2 – (2015)  \
# 0                   NaN                   NaN                    NaN
# 1                   NaN                   NaN                    NaN
# 2                   NaN                   NaN                    NaN
# 3                   NaN                   NaN                    NaN
# 4                   NaN                   NaN                    NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2015)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
#   Foret sur sol hydromorphe-Niveau 3-(2015) Foret dense - Niveau 3-(2015)  \
# 0                                       NaN                           NaN
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       NaN                           NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2015) EH-Niveau 2 (2015)  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
#
#   Infrastructures-Niveau 3(2015) TG-Niveau 2(2015) Changement 2015-2020  \
# 0                            NaN               NaN                  NaN
# 1                            NaN               NaN                  NaN
# 2                            NaN               NaN                  NaN
# 3                            NaN               NaN                  NaN
# 4                            NaN               NaN                  NaN
#
#   Moteur de deforestation 2015-2020  Annee de Degradation 2015-2020  \
# 0                               NaN                             NaN
# 1                               NaN                             NaN
# 2                               NaN                             NaN
# 3                               NaN                             NaN
# 4                               NaN                             NaN
#
#   Moteur de degradation 2015-2020  Annee de Deforestation 2015-2020  \
# 0                             NaN                               NaN
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                             NaN                               NaN
#
#    Gain 2015-2020 Occupation 2022 TF - Niveau 2 – (2022)  \
# 0             NaN             NaN                    NaN
# 1             NaN             NaN                    NaN
# 2             NaN             NaN                    NaN
# 3             NaN             NaN                    NaN
# 4             NaN             NaN                    NaN
#
#   Foret dense- Niveau 3 - (2022) Foret sur sol hydromorphe-Niveau 3-(2022)  \
# 0                            NaN                                       NaN
# 1                            NaN                                       NaN
# 2                            NaN                                       NaN
# 3                            NaN                                       NaN
# 4                            NaN                                       NaN
#
#   Plantation forestiere ou reboisement-Niveau 3-(2022)  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
#
#   Foret secondaire ou degradee-Niveau 3-(2022) TG-Niveau 2 (2022)  \
# 0                                          NaN                NaN
# 1                                          NaN                NaN
# 2                                          NaN                NaN
# 3                                          NaN                NaN
# 4                                          NaN                NaN
#
#   EH-Niveau 2 (2022) Infrastructures-Niveau 3(2022) TC-Niveau-2 (2022)  \
# 0                NaN                            NaN                NaN
# 1                NaN                            NaN                NaN
# 2                NaN                            NaN                NaN
# 3                NaN                            NaN                NaN
# 4                NaN                            NaN                NaN
#
#   Amenagement agricole-Niveau-3 (2022)  Cafe-Niveau-3 (2022)  \
# 0                                  NaN                   NaN
# 1                                  NaN                   NaN
# 2                                  NaN                   NaN
# 3                                  NaN                   NaN
# 4                                  NaN                   NaN
#
#   Hevea-Niveau-3 (2022) Cacao-Niveau-3 (2022) AT-Niveau 2 (2022)  \
# 0                   NaN                   NaN                NaN
# 1                   NaN                   NaN                NaN
# 2                   NaN                   NaN                NaN
# 3                   NaN                   NaN                NaN
# 4                   NaN                   NaN                NaN
#
#   TH-Niveau 2 (2022) Plan eau-Niveau 3(2022)  \
# 0                NaN                     NaN
# 1                NaN                     NaN
# 2                NaN                     NaN
# 3                NaN                     NaN
# 4                NaN                     NaN
#
#   Cours et voie eau-Niveau 3 (2022) Changement 2020-2022  \
# 0                               NaN                  NaN
# 1                               NaN                  NaN
# 2                               NaN                  NaN
# 3                               NaN                  NaN
# 4                               NaN                  NaN
#
#    Annee de Deforestation 2020-2022 Moteur de deforestation 2020-2022  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#    Gain 2020-2022  Annee de Degradation 2020-2022  \
# 0             NaN                             NaN
# 1             NaN                             NaN
# 2             NaN                             NaN
# 3             NaN                             NaN
# 4             NaN                             NaN
#
#   Moteur de degradation 2020-2022 Confiance Ajouter un commentaire  field_1_1  \
# 0                             NaN       NaN                    NaN        NaN
# 1                             NaN       NaN                    NaN        NaN
# 2                             NaN       NaN                    NaN        NaN
# 3                             NaN       NaN                    NaN        NaN
# 4                             NaN       NaN                    NaN        NaN
#
#    prob_chang  str_dal_ne  ID  INT1_2000  INT1_2010  INT1_2015  INT1_2020  \
# 0         NaN         NaN NaN        NaN        NaN        NaN        NaN
# 1         NaN         NaN NaN        NaN        NaN        NaN        NaN
# 2         NaN         NaN NaN        NaN        NaN        NaN        NaN
# 3         NaN         NaN NaN        NaN        NaN        NaN        NaN
# 4         NaN         NaN NaN        NaN        NaN        NaN        NaN
#
#    INT1_2021 CHG_00_10 CHG_10_15 CHG_15_20 CHG_20_21  IC COMMENT phyto  \
# 0        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
# 1        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
# 2        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
# 3        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
# 4        NaN       NaN       NaN       NaN       NaN NaN     NaN   NaN
#
#    str_dal_FA INT1_PI  INT2_2000  INT2_2010  INT2_2015  INT2_2020  INT2_2021  \
# 0         NaN     NaN        NaN        NaN        NaN        NaN        NaN
# 1         NaN     NaN        NaN        NaN        NaN        NaN        NaN
# 2         NaN     NaN        NaN        NaN        NaN        NaN        NaN
# 3         NaN     NaN        NaN        NaN        NaN        NaN        NaN
# 4         NaN     NaN        NaN        NaN        NaN        NaN        NaN
#
#   INT2_PI CHG2_00_10 CHG2_10_15 CHG2_15_20 CHG2_20_21 COMMENT.  \
# 0     NaN        NaN        NaN        NaN        NaN      NaN
# 1     NaN        NaN        NaN        NaN        NaN      NaN
# 2     NaN        NaN        NaN        NaN        NaN      NaN
# 3     NaN        NaN        NaN        NaN        NaN      NaN
# 4     NaN        NaN        NaN        NaN        NaN      NaN
#
#                                                layer  plots_id
# 0  accord_juin_2023_835_points.xlsx - ceo_835_points         1
# 1  accord_juin_2023_835_points.xlsx - ceo_835_points         2
# 2  accord_juin_2023_835_points.xlsx - ceo_835_points         3
# 3  accord_juin_2023_835_points.xlsx - ceo_835_points         4
# 4  accord_juin_2023_835_points.xlsx - ceo_835_points         5

# %%
trn_gdf = py_helpers.geojson_to_gdf('/home/sepal-user/module_results/esbae/CAFI/04_Dataset_Augmentation/Landsat/1_change.geojson')
trn_gdf.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 trn_gdf = py_helpers.geojson_to_gdf('/home/sepal-user/module_results/esbae/CAFI/04_Dataset_Augmentation/Landsat/1_change.geojson')
#       2 trn_gdf.columns
#
# NameError: name 'py_helpers' is not defined

# %% [markdown]
# ##### merge all ceo files

# %%
#make a list of the ceo files first
ceo_files = [ceo1, ceo2, ceo3,ceo4,ceo5]

# %% [markdown]
# ##### add a column named "interpreted" which = 1 when the point has been validated in CEO, otherwise 0
# ##### count the number of validated points per ceo file
# ##### replace forest and non-forest types with codes

# %%
# List to store the modified DataFrames
modified_ceo_files = []

# Initialize collection counter
collection_counter = 1

for i, ceo in enumerate(ceo):
       
    # Sort the DataFrame by 'date' in descending order
    ceo.sort_values(by='collection_time', ascending=True, inplace=True)

    # Remove duplicates keeping the last occurrence (the most recent date)
    ceo.drop_duplicates(subset='pl_point_id', keep='first', inplace=True)

    # Reset the index
    ceo.reset_index(drop=True, inplace=True)
    
    # Add 'collection' column with an increasing number
    ceo['collection'] = collection_counter
    
    # Add 'interpreted' column with 1 when 'email' is not null, otherwise 0
    ceo['interpreted'] = np.where(ceo['email'].notna(), 1, 0)
    
    # Calculate total count for each 'interpreted' value
    interpreted_counts = ceo['interpreted'].value_counts().to_dict()
    
    # Append the modified DataFrame to the list
    modified_ceo_files.append(ceo)
    
    # Print count for the current DataFrame
    print(f"ceo {i + 1} # of validated points: {interpreted_counts.get(1, 0)}, # of not validated points: {interpreted_counts.get(0, 0)}")
    
    # Increment the collection counter
    collection_counter += 1

# Concatenate the modified DataFrames into one merged DataFrame
merged_ceo = pd.concat(modified_ceo_files, ignore_index=True)


# Specify the columns you want to keep in the merged DataFrame
columns_to_keep = ['plotid', 'sampleid', 'lon', 'lat', 'email', 'flagged', 'collection_time', 'analysis_duration', 
                    'sample_geom', 'pl_point_id', 'pl_chg_prob', 'pl_simple_combined', 'pl_strata', 'forêt ou non-forêt en 2015?', "Y'a t'il de la régéneration", 
                    'Changement entre 2015-2022', 'Type de Changement (2015-2022)', 'Exploitation forestière artisanale (<5ha)', 
                    'Activité minière artisanale', 'Infrastructure routière', 'Infrastructure d’urbanisation ou habitations', 
                    'Exploitation forestière industrielle (>5ha)', 'Autre moteur', 'Descriptif autre moteur', 'Activité minière industrielle', 
                    'Agriculture industrielle', 'Agriculture paysanne', 'Année de Changement', 'Type de non-forêt en 2015', 'Type de forêt en 2015', 'Commentaires', 'collection', 'interpreted']

# Select only the specified columns
merged_ceo = merged_ceo[columns_to_keep]

# Create a dictionary to map old column names to new column names
column_mapping = {
    'pl_point_id': 'point_id',
    'pl_chg_prob': 'chg_prob', 
    'pl_simple_combined': 'simple_combined', 
    'pl_strata': 'stratum',
    'forêt ou non-forêt en 2015?': 'Ref_FNF_2015', 
    "Y'a t'il de la régéneration": 'Ref_Regeneration',
    'Changement entre 2015-2022': 'Ref_Change_1522', 
    'Type de Changement (2015-2022)': 'Ref_Change_Type_1522', 
    'Exploitation forestière artisanale (<5ha)': 'ArtFor',
    'Activité minière artisanale': 'ArtMine',
    'Infrastructure routière': 'InfraR', 
    'Infrastructure d’urbanisation ou habitations': 'Urb',
    'Exploitation forestière industrielle (>5ha)':'IndFor', 
    'Autre moteur': 'Other', 
    'Descriptif autre moteur': 'Other_Desc', 
    'Activité minière industrielle': 'IndMine', 
    'Agriculture industrielle': 'IndAg', 
    'Agriculture paysanne': 'ArtAg', 
    'Année de Changement': 'Ref_Year', 
    'Type de non-forêt en 2015':'Ref_NFType', 
    'Type de forêt en 2015':'Ref_FType'
}

# Use the rename() method to rename the columns
merged_ceo = merged_ceo.rename(columns=column_mapping)

# Define the replacements as a dictionary
replace_dict = {
    'Ref_FNF_2015': {'non-forêt': '0', 'forêt': '1'},
    'Ref_FType': {'1 - forêt dense': '1', '2 - forêt dense sèche': '2', '3 - forêt secondaire': '3','4 - forêt claire sèche': '4','7 - forêt mangrove': '7',
                 '8 - forêt marécageuse': '8', '9 - forêt galérie': '9','10 - plantation forestière': '10', '11- savane arborée': '11'},
    'Ref_NFType': {'12 - savane arbustive': '12', '13 - savane herbacée': '13', '14 - prairie aquatique': '14', '15 - sol nu végétation éparse': '15',
                  '16 - terres cultivées': '16', '17 - zone baties': '17', '18 - eau': '18'},
    'Ref_Change_1522': {'oui':'1','non':'0'},
    'ArtFor':{'oui':'1','non':'0'},
    'IndFor':{'oui':'1','non':'0'},
    'ArtAg':{'oui':'1','non':'0'},
    'IndAg':{'oui':'1','non':'0'},
    'ArtMine':{'oui':'1','non':'0'},
    'IndMine':{'oui':'1','non':'0'},
    'Urb':{'oui':'1','non':'0'},
    'InfraR':{'oui':'1','non':'0'},
    'Other':{'oui':'1','non':'0'}
}

# Use the replace() method to replace strings in specified columns
merged_ceo.replace(replace_dict, inplace=True)

# %%
merged_ceo_interpreted = merged_ceo[merged_ceo['interpreted'] == 1]

# %%
ceo_column_names = merged_ceo_interpreted.columns.tolist()
# Print the list of column names
print(ceo_column_names)

# %%
merged_ceo_interpreted.head()

# %%
merged_ceo_interpreted = merged_ceo_interpreted.sort_values(by='collection', ascending=True)

# Remove duplicates keeping the last occurrence (the most recent date)
merged_ceo_nodup = merged_ceo_interpreted.drop_duplicates(subset='point_id', keep='first')

# Reset the index
merged_ceo_nodup = merged_ceo_nodup.reset_index(drop=True)

# %%
merged_ceo_nodup['Ref_FNF_2015'].value_counts()

# %%
merged_ceo_nodup['Ref_Change_1522'].value_counts()

# %%
merged_ceo_nodup['Ref_Change_Type_1522'].value_counts()

# %%
merged_ceo_nodup['interpreted'].value_counts()

# %%
merged_ceo_nodup['collection'].value_counts()

# %% [markdown]
# ##### Check if values in 'pointid' are unique

# %%
# this might take some time
#unique_check = merged_ceo_nodup['point_id'].nunique() == len(merged_ceo_nodup['point_id'])

# Print the result
#if unique_check:
#    print("All values are unique!")
#else:
#    print("F$%§!")

# %% [markdown]
# ##### if there are duplicates determine which points and which project (collection)

# %%
# Find duplicate values in the 'ID' column
#duplicate_ids = merged_ceo_nodup[merged_ceo_nodup.duplicated(subset='point_id', keep='first')]

# If you want to print specific columns along with duplicates, you can do:
# For example, print only 'ID' and 'Name' columns
#print("\nDuplicate Rows with 'ID' and 'Name':")
#print(duplicate_ids[['point_id', 'collection']])
#len(duplicate_ids)

# %%
#merged_ceo_nodup.head()

# %% [markdown]
# ## add new columns for change and year

# %% [markdown]
# #### clean up columns and replace values

# %%
def f(x):
  if x['Ref_FNF_2015'] == '0' : return 'NF'
  elif x['Ref_Change_Type_1522'] == 'déforestation': return 'Def'
  elif x['Ref_Change_Type_1522'] == 'dégradation' : return 'Deg'
  else: return 'Stable'

merged_ceo_nodup['Ref_Change_Type_1522'] = merged_ceo_nodup.apply(f, axis=1)
merged_ceo_nodup['Ref_Change_Type_1522'].value_counts()

# %%
def y(x):
  if x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2016: return 'Def2016'
  elif x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2017: return 'Def2017'
  elif x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2018: return 'Def2018'
  elif x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2019: return 'Def2019'
  elif x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2020: return 'Def2020'
  elif x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2021: return 'Def2021'
  elif x['Ref_Change_Type_1522'] == 'Def' and x['Ref_Year'] == 2022: return 'Def2022'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2016: return 'Deg2016'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2017: return 'Deg2017'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2018: return 'Deg2018'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2019: return 'Deg2019'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2020: return 'Deg2020'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2021: return 'Deg2021'
  elif x['Ref_Change_Type_1522'] == 'Deg' and x['Ref_Year'] == 2022: return 'Deg2022'
  elif x['Ref_Change_Type_1522'] == 'NF' : return 'NF'
  elif x['Ref_Change_Type_1522'] == 'Stable' : return 'Stable'
  else: return ''

merged_ceo_nodup['Ref_Change_Year_1522'] = merged_ceo_nodup.apply(y, axis=1)

annual_counts = merged_ceo_nodup['Ref_Change_Year_1522'].value_counts()
annual_counts = annual_counts.sort_index()
print(annual_counts)

# %%
merged_ceo_nodup['Def2016'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2016', 1, 0)
merged_ceo_nodup['Def2017'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2017', 1, 0)
merged_ceo_nodup['Def2018'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2018', 1, 0)
merged_ceo_nodup['Def2019'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2019', 1, 0)
merged_ceo_nodup['Def2020'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2020', 1, 0)
merged_ceo_nodup['Def2021'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2021', 1, 0)
merged_ceo_nodup['Def2022'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Def2022', 1, 0)

# %%
merged_ceo_nodup['Deg2016'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2016', 1, 0)
merged_ceo_nodup['Deg2017'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2017', 1, 0)
merged_ceo_nodup['Deg2018'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2018', 1, 0)
merged_ceo_nodup['Deg2019'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2019', 1, 0)
merged_ceo_nodup['Deg2020'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2020', 1, 0)
merged_ceo_nodup['Deg2021'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2021', 1, 0)
merged_ceo_nodup['Deg2022'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Deg2022', 1, 0)

# %%
merged_ceo_nodup['Defall'] = np.where(merged_ceo_nodup['Ref_Change_Type_1522'] == 'Def', 1, 0)
merged_ceo_nodup['Degall'] = np.where(merged_ceo_nodup['Ref_Change_Type_1522'] == 'Deg', 1, 0)

# %%
merged_ceo_nodup['Stable'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'Stable', 1, 0)
merged_ceo_nodup['NF'] = np.where(merged_ceo_nodup['Ref_Change_Year_1522'] == 'NF', 1, 0)

# %%
annual_counts.sum()

# %%
#check points by change and stratum
ceo_table = pd.pivot_table(merged_ceo_nodup, values='interpreted', index=['stratum'],
                       columns=['Ref_Change_Year_1522'], aggfunc="count")
ceo_table

# %%
#export cleaned CEO data
ceo_out = '/home/sepal-user/module_results/esbae/GAB/GAB_esbae_all_ceo_clean.csv'
merged_ceo_nodup.to_csv(ceo_out,index=True)

# %%
#merged_ceo_nodup = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/GAB_esbae_all_ceo_clean.csv')

# %% [markdown]
# #### read all esbae points with augmented data (output from script 5a)

# %%
# Read the CSV files
#DRC
#esbae = pd.read_csv('/home/sepal-user/module_results/esbae/DRC/DRC_esbae_2015_2022_model.csv')
#GAB
#merged_ceo_nodup = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/GAB_esbae_all_ceo_clean.csv')
esbae = pd.read_csv('/home/sepal-user/module_results/esbae/GAB/GAB_esbae_2015_2022_model.csv')
len(esbae)
# Out:
# 222878

# %% [markdown]
# ##### Rename columns to be same as ceo file

# %%
esbae = esbae.rename(columns={'PLOTID': 'plotid'})
esbae = esbae.rename(columns={'LAT': 'lat'})
esbae = esbae.rename(columns={'LON': 'lon'})

# %%
print(esbae.dtypes)
# Out:
# images                    int64
# mon_images                int64
# bfast_change_date       float64
# bfast_magnitude         float64
# bfast_means             float64
# cusum_change_date       float64
# cusum_confidence        float64
# cusum_magnitude         float64
# red_mean                float64
# red_sd                  float64
# red_min                 float64
# red_max                 float64
# nir_mean                float64
# nir_sd                  float64
# nir_min                 float64
# nir_max                 float64
# swir1_mean              float64
# swir1_sd                float64
# swir1_min               float64
# swir1_max               float64
# swir2_mean              float64
# swir2_sd                float64
# swir2_min               float64
# swir2_max               float64
# ndfi_mean               float64
# ndfi_sd                 float64
# ndfi_min                float64
# ndfi_max                float64
# brightness_mean         float64
# brightness_sd           float64
# brightness_min          float64
# brightness_max          float64
# greenness_mean          float64
# greenness_sd            float64
# greenness_min           float64
# greenness_max           float64
# wetness_mean            float64
# wetness_sd              float64
# wetness_min             float64
# wetness_max             float64
# bs_slope_mean           float64
# bs_slope_sd             float64
# bs_slope_max            float64
# bs_slope_min            float64
# ccdc_change_date        float64
# ccdc_magnitude          float64
# aspect                  float64
# dw_class_mode           float64
# dw_tree_prob__max       float64
# dw_tree_prob__min       float64
# dw_tree_prob__stdDev    float64
# dw_tree_prob_mean       float64
# elevation               float64
# esa_lc20                float64
# esa_lc21                float64
# esri_lc17               float64
# esri_lc18               float64
# esri_lc19               float64
# esri_lc20               float64
# esri_lc21               float64
# gfc_gain                float64
# gfc_loss                float64
# gfc_lossyear            float64
# gfc_tc00                float64
# lang_tree_height        float64
# potapov_tree_height     float64
# slope                   float64
# tmf_2016                float64
# tmf_2017                float64
# tmf_2018                float64
# tmf_2019                float64
# tmf_2020                float64
# tmf_defyear             float64
# tmf_degyear             float64
# tmf_main                float64
# tmf_sub                 float64
# geometry                 object
# point_id                  int64
# cnc_1520                float64
# chg_prob                float64
# simple_combined         float64
# stratum                   int64
# kmeans                    int64
# plotid                    int64
# lon                     float64
# lat                     float64
# dtype: object

# %%
len(esbae)
# Out:
# 222878

# %%
eSBAE_cols = esbae.columns
eSBAE_cols
# Out:
# Index(['images', 'mon_images', 'bfast_change_date', 'bfast_magnitude',
#        'bfast_means', 'cusum_change_date', 'cusum_confidence',
#        'cusum_magnitude', 'red_mean', 'red_sd', 'red_min', 'red_max',
#        'nir_mean', 'nir_sd', 'nir_min', 'nir_max', 'swir1_mean', 'swir1_sd',
#        'swir1_min', 'swir1_max', 'swir2_mean', 'swir2_sd', 'swir2_min',
#        'swir2_max', 'ndfi_mean', 'ndfi_sd', 'ndfi_min', 'ndfi_max',
#        'brightness_mean', 'brightness_sd', 'brightness_min', 'brightness_max',
#        'greenness_mean', 'greenness_sd', 'greenness_min', 'greenness_max',
#        'wetness_mean', 'wetness_sd', 'wetness_min', 'wetness_max',
#        'bs_slope_mean', 'bs_slope_sd', 'bs_slope_max', 'bs_slope_min',
#        'ccdc_change_date', 'ccdc_magnitude', 'aspect', 'dw_class_mode',
#        'dw_tree_prob__max', 'dw_tree_prob__min', 'dw_tree_prob__stdDev',
#        'dw_tree_prob_mean', 'elevation', 'esa_lc20', 'esa_lc21', 'esri_lc17',
#        'esri_lc18', 'esri_lc19', 'esri_lc20', 'esri_lc21', 'gfc_gain',
#        'gfc_loss', 'gfc_lossyear', 'gfc_tc00', 'lang_tree_height',
#        'potapov_tree_height', 'slope', 'tmf_2016', 'tmf_2017', 'tmf_2018',
#        'tmf_2019', 'tmf_2020', 'tmf_defyear', 'tmf_degyear', 'tmf_main',
#        'tmf_sub', 'geometry', 'point_id', 'cnc_1520', 'chg_prob',
#        'simple_combined', 'stratum', 'kmeans', 'plotid', 'lon', 'lat'],
#       dtype='object')

# %% [markdown]
# ### Merge ceo and sbae tables
# #### replace validated points in esbae points

# %%
#make list of point_ids of validated points
validated_id_list = merged_ceo_nodup['point_id'].tolist()
len(validated_id_list)
# Out:
# 6539

# %%
# Merge ceo and sbae on "pointid" with an outer join
esbae_ceo = pd.merge(esbae, merged_ceo_nodup, on='point_id', how='outer')

# %%
# Fill NaN values in 'stratum' with values from the esbae DataFrame
esbae_ceo['stratum'] = esbae_ceo['stratum_y'].fillna(esbae_ceo['stratum_x'])

# %%
len(esbae_ceo)
# Out:
# 222878

# %%
esbae_ceo.head()
# Out:
#    images  mon_images  bfast_change_date  bfast_magnitude  bfast_means  \
# 0      48          26           2016.041      -181.454315    -1.639592
# 1      43          24           2016.129      5686.856934     3.850222
# 2      37          23           2021.077       889.901794     1.144007
# 3      32          20           2018.011      -212.911392    -0.766407
# 4      43          22           2016.677       343.551605     0.471041
#
#    cusum_change_date  cusum_confidence  cusum_magnitude     red_mean  \
# 0           2020.400          0.375197      3861.461538  9599.660256
# 1           2019.151          0.018619      1780.680556  9744.340278
# 2           2021.690         -0.029096      1450.304348  9635.413043
# 3           2016.984          0.194783      1930.883333  9590.675000
# 4           2016.436          0.300318      4431.090909  9607.431818
#
#        red_sd  red_min  red_max     nir_mean      nir_sd  nir_min  nir_max  \
# 0  448.342959   8149.0  10000.0  9599.660256  448.342959   8149.0  10000.0
# 1  345.157588   8472.0  10000.0  9744.340278  345.157588   8472.0  10000.0
# 2  404.692043   8307.0  10000.0  9635.413043  404.692043   8307.0  10000.0
# 3  326.133895   8815.0  10000.0  9590.675000  326.133895   8815.0  10000.0
# 4  662.563232   6879.0  10000.0  9607.431818  662.563232   6879.0  10000.0
#
#     swir1_mean    swir1_sd  swir1_min  swir1_max   swir2_mean    swir2_sd  \
# 0  9599.660256  448.342959     8149.0    10000.0  9599.660256  448.342959
# 1  9744.340278  345.157588     8472.0    10000.0  9744.340278  345.157588
# 2  9635.413043  404.692043     8307.0    10000.0  9635.413043  404.692043
# 3  9590.675000  326.133895     8815.0    10000.0  9590.675000  326.133895
# 4  9607.431818  662.563232     6879.0    10000.0  9607.431818  662.563232
#
#    swir2_min  swir2_max    ndfi_mean     ndfi_sd  ndfi_min  ndfi_max  \
# 0     8149.0    10000.0  9599.660256  448.342959    8149.0   10000.0
# 1     8472.0    10000.0  9744.340278  345.157588    8472.0   10000.0
# 2     8307.0    10000.0  9635.413043  404.692043    8307.0   10000.0
# 3     8815.0    10000.0  9590.675000  326.133895    8815.0   10000.0
# 4     6879.0    10000.0  9607.431818  662.563232    6879.0   10000.0
#
#    brightness_mean  brightness_sd  brightness_min  brightness_max  \
# 0      9599.660256     448.342959          8149.0         10000.0
# 1      9744.340278     345.157588          8472.0         10000.0
# 2      9635.413043     404.692043          8307.0         10000.0
# 3      9590.675000     326.133895          8815.0         10000.0
# 4      9607.431818     662.563232          6879.0         10000.0
#
#    greenness_mean  greenness_sd  greenness_min  greenness_max  wetness_mean  \
# 0     9599.660256    448.342959         8149.0        10000.0   9599.660256
# 1     9744.340278    345.157588         8472.0        10000.0   9744.340278
# 2     9635.413043    404.692043         8307.0        10000.0   9635.413043
# 3     9590.675000    326.133895         8815.0        10000.0   9590.675000
# 4     9607.431818    662.563232         6879.0        10000.0   9607.431818
#
#    wetness_sd  wetness_min  wetness_max  bs_slope_mean  bs_slope_sd  \
# 0  448.342959       8149.0      10000.0      13.958219    70.383567
# 1  345.157588       8472.0      10000.0      -0.642127    26.124178
# 2  404.692043       8307.0      10000.0      44.244464    42.038331
# 3  326.133895       8815.0      10000.0      14.744563    30.981018
# 4  662.563232       6879.0      10000.0     204.169622    90.299033
#
#    bs_slope_max  bs_slope_min  ccdc_change_date  ccdc_magnitude  aspect  \
# 0    193.584787   -138.033823          2020.400     -632.011504   128.0
# 1     60.085454   -103.812423          2016.107     4552.756313   118.0
# 2    164.402831   -101.459056             0.000        0.000000   161.0
# 3    153.492013    -77.202391          2021.318       61.988871    65.0
# 4    437.393554    -12.191784             0.000        0.000000    92.0
#
#    dw_class_mode  dw_tree_prob__max  dw_tree_prob__min  dw_tree_prob__stdDev  \
# 0            1.0               73.0                7.0                  18.0
# 1            1.0               73.0                3.0                  28.0
# 2            1.0               74.0               57.0                   4.0
# 3            1.0               74.0                9.0                  18.0
# 4            1.0               74.0               55.0                   5.0
#
#    dw_tree_prob_mean   elevation  esa_lc20  esa_lc21  esri_lc17  esri_lc18  \
# 0               67.0  207.340393      10.0      10.0        2.0        2.0
# 1               55.0  199.150024      10.0      10.0        2.0        2.0
# 2               71.0  568.627991      10.0      10.0        2.0        2.0
# 3               66.0  594.630798      10.0      10.0        2.0        2.0
# 4               71.0  577.762207      10.0      10.0        2.0        2.0
#
#    esri_lc19  esri_lc20  esri_lc21  gfc_gain  gfc_loss  gfc_lossyear  \
# 0        2.0        2.0        2.0       0.0       0.0           NaN
# 1        2.0        2.0        2.0       0.0       0.0           NaN
# 2        2.0        2.0        2.0       0.0       0.0           NaN
# 3        2.0        2.0        2.0       0.0       0.0           NaN
# 4        2.0        2.0        2.0       0.0       0.0           NaN
#
#    gfc_tc00  lang_tree_height  potapov_tree_height  slope  tmf_2016  tmf_2017  \
# 0      90.0              40.0                 33.0    3.0       1.0       1.0
# 1      90.0              34.0                 36.0    2.0       1.0       1.0
# 2      90.0              28.0                 26.0   11.0       1.0       1.0
# 3      95.0              31.0                 30.0    4.0       1.0       1.0
# 4      90.0              33.0                 34.0    4.0       1.0       1.0
#
#    tmf_2018  tmf_2019  tmf_2020  tmf_defyear  tmf_degyear  tmf_main  tmf_sub  \
# 0       1.0       1.0       1.0          0.0          0.0      10.0     10.0
# 1       1.0       1.0       1.0          0.0          0.0      10.0     10.0
# 2       1.0       1.0       1.0          0.0          0.0      10.0     10.0
# 3       1.0       1.0       1.0          0.0          0.0      10.0     10.0
# 4       1.0       1.0       1.0          0.0          0.0      10.0     10.0
#
#                                         geometry  point_id  cnc_1520  \
# 0  POINT (10.57392349486188 -1.5930084720027642)     76012       NaN
# 1   POINT (10.578907239035795 -1.58336462319752)     76013       NaN
# 2  POINT (12.064807356210801 1.3036806593856438)     76312       NaN
# 3   POINT (12.069790548758524 1.313328693505733)     76313       NaN
# 4   POINT (12.074773937046153 1.322976607263328)     76314       NaN
#
#    chg_prob_x  simple_combined_x  stratum_x  kmeans  plotid_x      lon_x  \
# 0    0.006000           0.006000          1       1     76012  10.573923
# 1    0.059333           0.059333          1       1     76013  10.578907
# 2    0.024667           0.024667          1       1     76312  12.064807
# 3    0.040667           0.040667          1       1     76313  12.069791
# 4    0.022667           0.022667          1       1     76314  12.074774
#
#       lat_x  Unnamed: 0  plotid_y  sampleid  lon_y  lat_y email flagged  \
# 0 -1.593008         NaN       NaN       NaN    NaN    NaN   NaN     NaN
# 1 -1.583365         NaN       NaN       NaN    NaN    NaN   NaN     NaN
# 2  1.303681         NaN       NaN       NaN    NaN    NaN   NaN     NaN
# 3  1.313329         NaN       NaN       NaN    NaN    NaN   NaN     NaN
# 4  1.322977         NaN       NaN       NaN    NaN    NaN   NaN     NaN
#
#   collection_time analysis_duration sample_geom  chg_prob_y  \
# 0             NaN               NaN         NaN         NaN
# 1             NaN               NaN         NaN         NaN
# 2             NaN               NaN         NaN         NaN
# 3             NaN               NaN         NaN         NaN
# 4             NaN               NaN         NaN         NaN
#
#    simple_combined_y  stratum_y  Ref_FNF_2015 Ref_Regeneration  \
# 0                NaN        NaN           NaN              NaN
# 1                NaN        NaN           NaN              NaN
# 2                NaN        NaN           NaN              NaN
# 3                NaN        NaN           NaN              NaN
# 4                NaN        NaN           NaN              NaN
#
#    Ref_Change_1522 Ref_Change_Type_1522  ArtFor  ArtMine  InfraR  Urb  IndFor  \
# 0              NaN                  NaN     NaN      NaN     NaN  NaN     NaN
# 1              NaN                  NaN     NaN      NaN     NaN  NaN     NaN
# 2              NaN                  NaN     NaN      NaN     NaN  NaN     NaN
# 3              NaN                  NaN     NaN      NaN     NaN  NaN     NaN
# 4              NaN                  NaN     NaN      NaN     NaN  NaN     NaN
#
#    Other Other_Desc  IndMine  IndAg  ArtAg  Ref_Year  Ref_NFType  Ref_FType  \
# 0    NaN        NaN      NaN    NaN    NaN       NaN         NaN        NaN
# 1    NaN        NaN      NaN    NaN    NaN       NaN         NaN        NaN
# 2    NaN        NaN      NaN    NaN    NaN       NaN         NaN        NaN
# 3    NaN        NaN      NaN    NaN    NaN       NaN         NaN        NaN
# 4    NaN        NaN      NaN    NaN    NaN       NaN         NaN        NaN
#
#   Commentaires  collection  interpreted Ref_Change_Year_1522  Def2016  \
# 0          NaN         NaN          NaN                  NaN      NaN
# 1          NaN         NaN          NaN                  NaN      NaN
# 2          NaN         NaN          NaN                  NaN      NaN
# 3          NaN         NaN          NaN                  NaN      NaN
# 4          NaN         NaN          NaN                  NaN      NaN
#
#    Def2017  Def2018  Def2019  Def2020  Def2021  Def2022  Deg2016  Deg2017  \
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Deg2018  Deg2019  Deg2020  Deg2021  Deg2022  Defall  Degall  Stable  NF  \
# 0      NaN      NaN      NaN      NaN      NaN     NaN     NaN     NaN NaN
# 1      NaN      NaN      NaN      NaN      NaN     NaN     NaN     NaN NaN
# 2      NaN      NaN      NaN      NaN      NaN     NaN     NaN     NaN NaN
# 3      NaN      NaN      NaN      NaN      NaN     NaN     NaN     NaN NaN
# 4      NaN      NaN      NaN      NaN      NaN     NaN     NaN     NaN NaN
#
#    stratum
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0

# %% [markdown]
# #### clean up _x and _y columns

# %%
merged_columns = esbae_ceo.columns.tolist()
print(merged_columns)
# Out:
# ['images', 'mon_images', 'bfast_change_date', 'bfast_magnitude', 'bfast_means', 'cusum_change_date', 'cusum_confidence', 'cusum_magnitude', 'red_mean', 'red_sd', 'red_min', 'red_max', 'nir_mean', 'nir_sd', 'nir_min', 'nir_max', 'swir1_mean', 'swir1_sd', 'swir1_min', 'swir1_max', 'swir2_mean', 'swir2_sd', 'swir2_min', 'swir2_max', 'ndfi_mean', 'ndfi_sd', 'ndfi_min', 'ndfi_max', 'brightness_mean', 'brightness_sd', 'brightness_min', 'brightness_max', 'greenness_mean', 'greenness_sd', 'greenness_min', 'greenness_max', 'wetness_mean', 'wetness_sd', 'wetness_min', 'wetness_max', 'bs_slope_mean', 'bs_slope_sd', 'bs_slope_max', 'bs_slope_min', 'ccdc_change_date', 'ccdc_magnitude', 'aspect', 'dw_class_mode', 'dw_tree_prob__max', 'dw_tree_prob__min', 'dw_tree_prob__stdDev', 'dw_tree_prob_mean', 'elevation', 'esa_lc20', 'esa_lc21', 'esri_lc17', 'esri_lc18', 'esri_lc19', 'esri_lc20', 'esri_lc21', 'gfc_gain', 'gfc_loss', 'gfc_lossyear', 'gfc_tc00', 'lang_tree_height', 'potapov_tree_height', 'slope', 'tmf_2016', 'tmf_2017', 'tmf_2018', 'tmf_2019', 'tmf_2020', 'tmf_defyear', 'tmf_degyear', 'tmf_main', 'tmf_sub', 'geometry', 'point_id', 'cnc_1520', 'chg_prob_x', 'simple_combined_x', 'stratum_x', 'kmeans', 'plotid_x', 'lon_x', 'lat_x', 'Unnamed: 0', 'plotid_y', 'sampleid', 'lon_y', 'lat_y', 'email', 'flagged', 'collection_time', 'analysis_duration', 'sample_geom', 'chg_prob_y', 'simple_combined_y', 'stratum_y', 'Ref_FNF_2015', 'Ref_Regeneration', 'Ref_Change_1522', 'Ref_Change_Type_1522', 'ArtFor', 'ArtMine', 'InfraR', 'Urb', 'IndFor', 'Other', 'Other_Desc', 'IndMine', 'IndAg', 'ArtAg', 'Ref_Year', 'Ref_NFType', 'Ref_FType', 'Commentaires', 'collection', 'interpreted', 'Ref_Change_Year_1522', 'Def2016', 'Def2017', 'Def2018', 'Def2019', 'Def2020', 'Def2021', 'Def2022', 'Deg2016', 'Deg2017', 'Deg2018', 'Deg2019', 'Deg2020', 'Deg2021', 'Deg2022', 'Defall', 'Degall', 'Stable', 'NF', 'stratum']

# %%
#drop and columns
esbae_ceo = esbae_ceo.drop(['plotid_y', 'lon_y', 'lat_y','chg_prob_y', 'simple_combined_y', 'stratum_y', 'stratum_x'], axis=1)
esbae_ceo.columns = esbae_ceo.columns.str.replace('_x', '')
esbae_ceo.columns = esbae_ceo.columns.str.replace('_y', '')

# %%
print(esbae_ceo.columns.values)
# Out:
# ['images' 'mon_images' 'bfast_change_date' 'bfast_magnitude' 'bfast_means'
#  'cusum_change_date' 'cusum_confidence' 'cusum_magnitude' 'red_mean'
#  'red_sd' 'red_min' 'red_max' 'nir_mean' 'nir_sd' 'nir_min' 'nir_max'
#  'swir1_mean' 'swir1_sd' 'swir1_min' 'swir1_max' 'swir2_mean' 'swir2_sd'
#  'swir2_min' 'swir2_max' 'ndfi_mean' 'ndfi_sd' 'ndfi_min' 'ndfi_max'
#  'brightness_mean' 'brightness_sd' 'brightness_min' 'brightness_max'
#  'greenness_mean' 'greenness_sd' 'greenness_min' 'greenness_max'
#  'wetness_mean' 'wetness_sd' 'wetness_min' 'wetness_max' 'bs_slope_mean'
#  'bs_slope_sd' 'bs_slope_max' 'bs_slope_min' 'ccdc_change_date'
#  'ccdc_magnitude' 'aspect' 'dw_class_mode' 'dw_tree_prob__max'
#  'dw_tree_prob__min' 'dw_tree_prob__stdDev' 'dw_tree_prob_mean'
#  'elevation' 'esa_lc20' 'esa_lc21' 'esri_lc17' 'esri_lc18' 'esri_lc19'
#  'esri_lc20' 'esri_lc21' 'gfc_gain' 'gfc_loss' 'gfc_lossyear' 'gfc_tc00'
#  'lang_tree_height' 'potapov_tree_height' 'slope' 'tmf_2016' 'tmf_2017'
#  'tmf_2018' 'tmf_2019' 'tmf_2020' 'tmf_defyear' 'tmf_degyear' 'tmf_main'
#  'tmf_sub' 'geometry' 'point_id' 'cnc_1520' 'chg_prob' 'simple_combined'
#  'kmeans' 'plotid' 'lon' 'lat' 'Unnamed: 0' 'sampleid' 'email' 'flagged'
#  'collection_time' 'analysis_duration' 'sample_geom' 'Ref_FNF_2015'
#  'Ref_Regeneration' 'Ref_Change_1522' 'Ref_Change_Type_1522' 'ArtFor'
#  'ArtMine' 'InfraR' 'Urb' 'IndFor' 'Other' 'Other_Desc' 'IndMine' 'IndAg'
#  'ArtAg' 'Ref_Year' 'Ref_NFType' 'Ref_FType' 'Commentaires' 'collection'
#  'interpreted' 'Ref_Change_Year_1522' 'Def2016' 'Def2017' 'Def2018'
#  'Def2019' 'Def2020' 'Def2021' 'Def2022' 'Deg2016' 'Deg2017' 'Deg2018'
#  'Deg2019' 'Deg2020' 'Deg2021' 'Deg2022' 'Defall' 'Degall' 'Stable' 'NF'
#  'stratum']

# %%
esbae_ceo['interpreted'] = esbae_ceo['interpreted'].fillna(0)
esbae_ceo['interpreted'] = esbae_ceo['interpreted'].astype(int)
esbae_ceo['interpreted'].value_counts(dropna=False)
# Out:
# 0    216339
# 1      6539
# Name: interpreted, dtype: int64

# %%
esbae_ceo['Ref_Change_Year_1522'].value_counts(dropna=False)
# Out:
# NaN        216339
# Stable       5070
# NF           1238
# Deg2022        38
# Deg2020        28
# Deg2021        26
# Deg2018        25
# Def2016        21
# Deg2019        16
# Deg2017        15
# Deg2016        14
# Def2022        13
# Def2017        13
# Def2021         7
# Def2018         7
# Def2020         6
# Def2019         2
# Name: Ref_Change_Year_1522, dtype: int64

# %%
#check points by change and stratum
points_strata = pd.pivot_table(esbae_ceo, values = 'point_id', index = 'Ref_Change_Year_1522',columns = 'stratum', aggfunc =  "count")
points_strata
# Out:
# stratum                 1.0     2.0     3.0
# Ref_Change_Year_1522
# Def2016                 NaN     2.0    19.0
# Def2017                 NaN     2.0    11.0
# Def2018                 NaN     NaN     7.0
# Def2019                 NaN     NaN     2.0
# Def2020                 NaN     1.0     5.0
# Def2021                 NaN     1.0     6.0
# Def2022                 NaN     6.0     7.0
# Deg2016                 NaN     2.0    12.0
# Deg2017                 NaN     1.0    14.0
# Deg2018                 NaN     1.0    24.0
# Deg2019                 NaN     NaN    16.0
# Deg2020                 NaN     4.0    24.0
# Deg2021                 NaN     5.0    21.0
# Deg2022                 NaN    11.0    27.0
# NF                      6.0   636.0   596.0
# Stable                297.0  3456.0  1317.0

# %%
esbae_ceo['stratum'].value_counts()

# %% [markdown]
# #### check for missing values

# %%
# Initialize a dictionary to store the counts by column
missing_counts = {}

# Count missing values and sum the counts by column
for column in eSBAE_cols:
    missing_counts[column] = esbae_ceo[column].isna().sum()

# Print the counts
print(missing_counts)

# %% [markdown]
# ##### plot deforestation points by year

# %%
#select the values you want to plot
values_to_plot = ['Def2016','Def2017','Def2018','Def2019','Def2020','Def2021','Def2022']

# Filter the DataFrame to include only the selected values
filtered_df = esbae_ceo[esbae_ceo['Ref_Change_Year_1522'].isin(values_to_plot)]

# Get the value counts and sort by index (alphabetically)
defvalue_counts = filtered_df['Ref_Change_Year_1522'].value_counts().sort_index()

# Plot the value counts as a bar graph
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
defvalue_counts.plot(kind='bar', color='skyblue')


# Set plot labels and title
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('# of def points per year')

# Show the plot
plt.show()

# %% [markdown]
# ##### plot degradation points by year

# %%
#plot DEG 
#select the values you want to plot
values_to_plot = ['Deg2016','Deg2017','Deg2018','Deg2019','Deg2020','Deg2021','Deg2022']

# Filter the DataFrame to include only the selected values
filtered_df = esbae_ceo[esbae_ceo['Ref_Change_Year_1522'].isin(values_to_plot)]

# Get the value counts and sort by index (alphabetically)
degvalue_counts = filtered_df['Ref_Change_Year_1522'].value_counts().sort_index()

# Plot the value counts as a bar graph
plt.figure(figsize=(8, 6))  # Optional: Set the figure size
degvalue_counts.plot(kind='bar', color='skyblue')


# Set plot labels and title
plt.xlabel('Category')
plt.ylabel('Count')
plt.title('# of deg points per year')

# Show the plot
plt.show()

# %%
print(esbae_ceo.columns.values)

# %%
merged_annual_counts = esbae_ceo['Ref_Change_Year_1522'].value_counts()
merged_annual_counts = merged_annual_counts.sort_index()
merged_annual_counts

# %%
esbae_ceo.describe()

# %%
print(esbae_ceo.dtypes)

# %% [markdown]
# ##### export merged esbae and ceo data to one csv file for next step

# %%
# if you want to remove all the eSBAE variables
#DRC
#esbae = esbae[['point_id', 'PLOTID', 'LAT','LON','stratum', 'chg_prob', 'simple_combined','NOM']]
#GAB
#esbae = esbae[['point_id', 'PLOTID', 'LAT','LON','stratum', 'chg_prob', 'simple_combined']]

# %%
esbae_ceo_data_out =  '/home/sepal-user/module_results/esbae/GAB/GAB_esbae_ceo_merge.csv'
esbae_ceo.to_csv(esbae_ceo_data_out,index=False)
#OR
#esbae_ceo[esbae_ceo_columns].to_csv(data_out,index=True)

# %% [markdown]
# #### now move on to calculation of areas - script 6b
